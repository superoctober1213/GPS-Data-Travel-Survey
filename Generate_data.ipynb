# %%
import geopandas as gpd
import trackintel as ti

# read pfs from csv file
pfs = ti.io.file.read_positionfixes_csv('data.csv', 
                                        columns={'user_id':'user_id', 'latitude':'latitude', 'longitude':'longitude', 'time':'tracked_at'},
                                        tz= 'America/New_York',
                                        crs ='EPSG:4326',
                                        index_col = 'ID')
# Out:
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/vy/m0tbb9cx2m176wk361h4ns900000gn/T/ipykernel_5411/461071409.py:1: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
pfs
# Out:
#                                            id                tracked_at  \
# ID
# 0        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:01-04:00
# 1        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:02-04:00
# 2        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:32-04:00
# 3        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:33-04:00
# 4        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:29:06-04:00
# ...                                       ...                       ...
# 5844271  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 02:31:55-04:00
# 5844272  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 03:27:04-04:00
# 5844273  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 23:18:01-04:00
# 5844274  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 23:59:04-04:00
# 5844275  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 23:59:53-04:00
#
#          user_id                        geom
# ID
# 0              0  POINT (-81.58150 30.27550)
# 1              0  POINT (-81.72430 30.31220)
# 2              0  POINT (-81.58150 30.27550)
# 3              0  POINT (-81.72430 30.31220)
# 4              0  POINT (-81.58150 30.27550)
# ...          ...                         ...
# 5844271     4058  POINT (-81.59753 30.36918)
# 5844272     4058  POINT (-81.59758 30.36919)
# 5844273     4058  POINT (-81.59223 30.36078)
# 5844274     4058  POINT (-81.59223 30.36078)
# 5844275     4058  POINT (-81.59224 30.36077)
#
# [5593588 rows x 4 columns]

# %%
# generate staypoints
pfs, sp = pfs.as_positionfixes.generate_staypoints(method='sliding', dist_threshold=100, time_threshold=2.0, gap_threshold = 1440, print_progress = True, include_last = True, n_jobs=-1)
# Out:
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/trackintel/io/file.py:5: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pygeos/io.py:89: UserWarning: The shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the PyGEOS GEOS version (3.10.4-CAPI-1.16.2). Conversions between both will be slow
#   warnings.warn(
# 100%|██████████| 5172/5172 [02:44<00:00, 31.52it/s]

# %%
pfs
# Out:
#                                            id                tracked_at  \
# ID
# 0        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:01-04:00
# 1        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:02-04:00
# 2        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:32-04:00
# 3        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:33-04:00
# 4        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:29:06-04:00
# ...                                       ...                       ...
# 5844271  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 02:31:55-04:00
# 5844272  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 03:27:04-04:00
# 5844273  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 23:18:01-04:00
# 5844274  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 23:59:04-04:00
# 5844275  f4e93347-c896-3325-83cd-69d751729be4 2022-10-24 23:59:53-04:00
#
#          user_id                        geom  staypoint_id
# ID
# 0              0  POINT (-81.58150 30.27550)          <NA>
# 1              0  POINT (-81.72430 30.31220)          <NA>
# 2              0  POINT (-81.58150 30.27550)          <NA>
# 3              0  POINT (-81.72430 30.31220)          <NA>
# 4              0  POINT (-81.58150 30.27550)          <NA>
# ...          ...                         ...           ...
# 5844271     4058  POINT (-81.59753 30.36918)        603050
# 5844272     4058  POINT (-81.59758 30.36919)        603050
# 5844273     4058  POINT (-81.59223 30.36078)        603051
# 5844274     4058  POINT (-81.59223 30.36078)        603051
# 5844275     4058  POINT (-81.59224 30.36077)        603051
#
# [5593588 rows x 5 columns]

# %%
sp
# Out:
#         user_id                started_at               finished_at  \
# id
# 0             0 2022-09-07 20:36:01-04:00 2022-09-07 21:21:37-04:00
# 1             0 2022-09-20 14:10:57-04:00 2022-09-20 14:13:46-04:00
# 2             0 2022-09-20 14:16:49-04:00 2022-09-20 23:40:41-04:00
# 3             0 2022-09-20 23:40:41-04:00 2022-09-20 23:47:54-04:00
# 4             0 2022-09-20 23:51:20-04:00 2022-09-21 01:32:10-04:00
# ...         ...                       ...                       ...
# 671785     5171 2022-10-28 22:25:22-04:00 2022-10-28 22:30:26-04:00
# 671786     5171 2022-10-28 22:32:17-04:00 2022-10-28 23:43:58-04:00
# 671787     5171 2022-10-28 23:43:58-04:00 2022-10-28 23:48:20-04:00
# 671788     5171 2022-10-28 23:53:51-04:00 2022-10-29 17:33:06-04:00
# 671789     5171 2022-10-29 17:36:49-04:00 2022-10-30 00:19:09-04:00
#
#                               geom
# id
# 0       POINT (-81.72430 30.31220)
# 1       POINT (-81.75290 30.27120)
# 2       POINT (-81.82171 30.28510)
# 3       POINT (-81.75290 30.27120)
# 4       POINT (-81.67558 30.36497)
# ...                            ...
# 671785  POINT (-81.74800 30.20161)
# 671786  POINT (-81.74847 30.20290)
# 671787  POINT (-81.76864 30.14110)
# 671788  POINT (-81.74723 30.20247)
# 671789  POINT (-81.97047 30.29001)
#
# [671790 rows x 4 columns]

# %%
# generate triplegs
pfs, tpls = pfs.as_positionfixes.generate_triplegs(sp, method='between_staypoints', gap_threshold = 1440)
# Out:
# /usr/local/lib/python3.9/site-packages/trackintel/preprocessing/positionfixes.py:498: UserWarning: The positionfixes with ids [1555854 1555855 1555886 ... 5800959 5800960 5800961] lead to invalid tripleg geometries. The resulting triplegs were omitted and the tripleg id of the positionfixes was set to nan
#   warnings.warn(warn_string)

# %%
pfs
# Out:
#                                            id                tracked_at  \
# ID
# 0        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:01-04:00
# 1        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:02-04:00
# 2        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:32-04:00
# 3        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:28:33-04:00
# 4        0015b634-5297-31bb-8e29-e54f3405b9ce 2022-09-07 20:29:06-04:00
# ...                                       ...                       ...
# 5837295  b53fe8fa-9e3d-301f-9b66-65e7d3b52190 2022-10-29 17:36:49-04:00
# 5837228  b53fe8fa-9e3d-301f-9b66-65e7d3b52190 2022-10-30 00:19:09-04:00
# 5837229  b53fe8fa-9e3d-301f-9b66-65e7d3b52190 2022-10-30 00:19:59-04:00
# 5837230  b53fe8fa-9e3d-301f-9b66-65e7d3b52190 2022-10-30 00:20:05-04:00
# 5837231  b53fe8fa-9e3d-301f-9b66-65e7d3b52190 2022-10-30 00:20:50-04:00
#
#          user_id                        geom  staypoint_id  tripleg_id
# ID
# 0              0  POINT (-81.58150 30.27550)          <NA>           0
# 1              0  POINT (-81.72430 30.31220)          <NA>           0
# 2              0  POINT (-81.58150 30.27550)          <NA>           0
# 3              0  POINT (-81.72430 30.31220)          <NA>           0
# 4              0  POINT (-81.58150 30.27550)          <NA>           0
# ...          ...                         ...           ...         ...
# 5837295     5171  POINT (-81.97047 30.29001)        671789        <NA>
# 5837228     5171  POINT (-81.73973 30.20432)          <NA>      152109
# 5837229     5171  POINT (-81.73973 30.20431)          <NA>      152109
# 5837230     5171  POINT (-81.74006 30.20414)          <NA>      152109
# 5837231     5171  POINT (-81.74005 30.20413)          <NA>      152109
#
# [5593588 rows x 6 columns]

# %%
tpls
# Out:
#         user_id                started_at               finished_at  \
# id
# 0             0 2022-09-07 20:28:01-04:00 2022-09-07 20:35:59-04:00
# 1             0 2022-09-07 21:21:37-04:00 2022-09-07 21:21:39-04:00
# 2             0 2022-09-20 14:08:22-04:00 2022-09-20 14:10:52-04:00
# 3             0 2022-09-20 14:13:46-04:00 2022-09-20 14:16:26-04:00
# 4             0 2022-09-20 23:47:54-04:00 2022-09-20 23:51:16-04:00
# ...         ...                       ...                       ...
# 152105     5170 2022-10-31 23:45:14-04:00 2022-10-31 23:48:44-04:00
# 152106     5171 2022-10-28 22:30:26-04:00 2022-10-28 22:31:08-04:00
# 152107     5171 2022-10-28 23:48:20-04:00 2022-10-28 23:53:40-04:00
# 152108     5171 2022-10-29 17:33:06-04:00 2022-10-29 17:36:48-04:00
# 152109     5171 2022-10-30 00:19:09-04:00 2022-10-30 00:20:50-04:00
#
#                                                      geom
# id
# 0       LINESTRING (-81.58150 30.27550, -81.72430 30.3...
# 1       LINESTRING (-81.58150 30.27550, -81.63610 30.2...
# 2       LINESTRING (-81.58670 30.35240, -81.75290 30.2...
# 3       LINESTRING (-81.68800 30.35620, -81.75290 30.2...
# 4       LINESTRING (-81.82170 30.28510, -81.75290 30.2...
# ...                                                   ...
# 152105  LINESTRING (-81.58577 30.36283, -81.58577 30.3...
# 152106  LINESTRING (-81.74959 30.20178, -81.74916 30.2...
# 152107  LINESTRING (-81.74633 30.17230, -81.74538 30.1...
# 152108  LINESTRING (-81.87941 30.30666, -81.74741 30.1...
# 152109  LINESTRING (-81.73973 30.20432, -81.73973 30.2...
#
# [143583 rows x 4 columns]

# %%
# Write positionfixes to csv file.
ti.io.file.write_positionfixes_csv(pfs, 'pfs.csv')

# %%
# Write staypoints to csv file.
ti.io.file.write_staypoints_csv(sp, 'staypoints.csv')

# %%
# Write triplegs to csv file.
ti.io.file.write_triplegs_csv(tpls, 'triplegs.csv')
