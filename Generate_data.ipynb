# %%
import geopandas as gpd
import trackintel as ti

# read pfs from csv file
pfs = ti.io.file.read_positionfixes_csv('data.csv', 
                                        columns={'user_id':'user_id', 'latitude':'latitude', 'longitude':'longitude', 'time':'tracked_at'},
                                        tz= 'America/New_York',
                                        crs ='EPSG:4326')
# Out:
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/vy/m0tbb9cx2m176wk361h4ns900000gn/T/ipykernel_8082/2255246439.py:1: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
pfs
# Out:
#               ID                                    id  \
# 0              0  0015b634-5297-31bb-8e29-e54f3405b9ce
# 1              1  0015b634-5297-31bb-8e29-e54f3405b9ce
# 2              2  0015b634-5297-31bb-8e29-e54f3405b9ce
# 3              3  0015b634-5297-31bb-8e29-e54f3405b9ce
# 4              4  0015b634-5297-31bb-8e29-e54f3405b9ce
# ...          ...                                   ...
# 5593583  5844271  f4e93347-c896-3325-83cd-69d751729be4
# 5593584  5844272  f4e93347-c896-3325-83cd-69d751729be4
# 5593585  5844273  f4e93347-c896-3325-83cd-69d751729be4
# 5593586  5844274  f4e93347-c896-3325-83cd-69d751729be4
# 5593587  5844275  f4e93347-c896-3325-83cd-69d751729be4
#
#                        tracked_at  user_id                        geom
# 0       2022-09-07 20:28:01-04:00        0  POINT (-81.58150 30.27550)
# 1       2022-09-07 20:28:02-04:00        0  POINT (-81.72430 30.31220)
# 2       2022-09-07 20:28:32-04:00        0  POINT (-81.58150 30.27550)
# ...

# %%
# generate staypoints
pfs, sp = pfs.as_positionfixes.generate_staypoints(method='sliding', dist_threshold=100, time_threshold=2.0, n_jobs=-1)
# Out:
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# ...

# %%
pfs
# Out:
#               ID                                    id  \
# 0              0  0015b634-5297-31bb-8e29-e54f3405b9ce
# 1              1  0015b634-5297-31bb-8e29-e54f3405b9ce
# 2              2  0015b634-5297-31bb-8e29-e54f3405b9ce
# 3              3  0015b634-5297-31bb-8e29-e54f3405b9ce
# 4              4  0015b634-5297-31bb-8e29-e54f3405b9ce
# ...          ...                                   ...
# 5593583  5844271  f4e93347-c896-3325-83cd-69d751729be4
# 5593584  5844272  f4e93347-c896-3325-83cd-69d751729be4
# 5593585  5844273  f4e93347-c896-3325-83cd-69d751729be4
# 5593586  5844274  f4e93347-c896-3325-83cd-69d751729be4
# 5593587  5844275  f4e93347-c896-3325-83cd-69d751729be4
#
#                        tracked_at  user_id                        geom  \
# 0       2022-09-07 20:28:01-04:00        0  POINT (-81.58150 30.27550)
# 1       2022-09-07 20:28:02-04:00        0  POINT (-81.72430 30.31220)
# 2       2022-09-07 20:28:32-04:00        0  POINT (-81.58150 30.27550)
# ...

# %%
sp
# Out:
#         user_id                started_at               finished_at  \
# id
# 0             0 2022-09-20 14:10:57-04:00 2022-09-20 14:13:46-04:00
# 1             0 2022-09-20 23:40:41-04:00 2022-09-20 23:47:54-04:00
# 2             0 2022-09-21 01:33:56-04:00 2022-09-21 01:36:24-04:00
# 3             0 2022-09-21 01:37:04-04:00 2022-09-21 01:39:10-04:00
# 4             0 2022-09-21 02:03:54-04:00 2022-09-21 02:08:44-04:00
# ...         ...                       ...                       ...
# 350992     5171 2022-10-28 14:16:55-04:00 2022-10-28 14:31:46-04:00
# 350993     5171 2022-10-28 20:15:35-04:00 2022-10-28 20:30:30-04:00
# 350994     5171 2022-10-28 20:30:30-04:00 2022-10-28 20:36:12-04:00
# 350995     5171 2022-10-28 22:25:22-04:00 2022-10-28 22:30:26-04:00
# 350996     5171 2022-10-28 23:43:58-04:00 2022-10-28 23:48:20-04:00
#
#                               geom
# id
# 0       POINT (-81.75290 30.27120)
# 1       POINT (-81.75290 30.27120)
# ...

# %%
# generate triplegs
pfs, tpls = pfs.as_positionfixes.generate_triplegs(sp, method='between_staypoints')
# Out:
# /usr/local/lib/python3.9/site-packages/trackintel/preprocessing/positionfixes.py:498: UserWarning: The positionfixes with ids [1485792 1485793 1485794 ... 5586946 5586964 5586965] lead to invalid tripleg geometries. The resulting triplegs were omitted and the tripleg id of the positionfixes was set to nan
#   warnings.warn(warn_string)

# %%
pfs
# Out:
#               ID                                    id  \
# 0              0  0015b634-5297-31bb-8e29-e54f3405b9ce
# 1              1  0015b634-5297-31bb-8e29-e54f3405b9ce
# 2              2  0015b634-5297-31bb-8e29-e54f3405b9ce
# 3              3  0015b634-5297-31bb-8e29-e54f3405b9ce
# 4              4  0015b634-5297-31bb-8e29-e54f3405b9ce
# ...          ...                                   ...
# 5587016  5837295  b53fe8fa-9e3d-301f-9b66-65e7d3b52190
# 5586949  5837228  b53fe8fa-9e3d-301f-9b66-65e7d3b52190
# 5586950  5837229  b53fe8fa-9e3d-301f-9b66-65e7d3b52190
# 5586951  5837230  b53fe8fa-9e3d-301f-9b66-65e7d3b52190
# 5586952  5837231  b53fe8fa-9e3d-301f-9b66-65e7d3b52190
#
#                        tracked_at  user_id                        geom  \
# 0       2022-09-07 20:28:01-04:00        0  POINT (-81.58150 30.27550)
# 1       2022-09-07 20:28:02-04:00        0  POINT (-81.72430 30.31220)
# 2       2022-09-07 20:28:32-04:00        0  POINT (-81.58150 30.27550)
# ...

# %%
tpls
# Out:
#         user_id                started_at               finished_at  \
# id
# 0             0 2022-09-07 20:28:01-04:00 2022-09-07 20:36:01-04:00
# 1             0 2022-09-07 21:21:37-04:00 2022-09-07 21:21:39-04:00
# 2             0 2022-09-20 14:08:22-04:00 2022-09-20 14:10:52-04:00
# 3             0 2022-09-20 14:13:46-04:00 2022-09-20 14:17:43-04:00
# 4             0 2022-09-20 23:47:54-04:00 2022-09-20 23:51:20-04:00
# ...         ...                       ...                       ...
# 535420     5171 2022-10-28 22:02:07-04:00 2022-10-28 22:03:29-04:00
# 535421     5171 2022-10-28 22:30:26-04:00 2022-10-28 22:32:17-04:00
# 535422     5171 2022-10-28 23:48:20-04:00 2022-10-28 23:53:59-04:00
# 535423     5171 2022-10-29 17:33:06-04:00 2022-10-29 17:36:49-04:00
# 535424     5171 2022-10-30 00:19:09-04:00 2022-10-30 00:20:50-04:00
#
#                                                      geom
# id
# 0       LINESTRING (-81.58150 30.27550, -81.72430 30.3...
# ...

# %%
# Write positionfixes to csv file.
ti.io.file.write_positionfixes_csv(pfs, 'pfs.csv')

# %%
# Write staypoints to csv file.
ti.io.file.write_staypoints_csv(sp, 'staypoints.csv')

# %%
# Write triplegs to csv file.
ti.io.file.write_triplegs_csv(tpls, 'triplegs.csv')
